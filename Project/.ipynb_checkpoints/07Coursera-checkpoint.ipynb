# %% [markdown]
# # Coursera Dataset Analysis for Tilto, Inc.

# %% [markdown]
# #  Introduction
# Tilto, Inc. is a Lithuanian education and technology company, registered in the United States. Tilto is planning to create a company with Coursera as a model. Coursera was founded by Daphne Koller and Andrew Ng in 2012 with a vision of providing life-transforming learning experiences to learners around the world. Today, Coursera is a global online learning platform that offers anyone, anywhere, access to online courses and degrees from leading universities and companies.
#
# In Lithuanian, Tilto means bridge. Tilto, Inc. plans to become an international company that impacts the world by making its citizens realize their innate potentials. Tilto's leaderhip wants to understand what makes Coursera successful. They also want to know what can be done better, so Tilto can become an even stronger organization than Coursera. This analysis will help Tilto achieve it's vision. For this analysis, I will work with a dataset provided by Coursea and obtained from Kaggle.

# %% [markdown]
# # Goals
#
# The goal of this project is to analyze Coursera's content offering and advise Tilto's leadership on how to move forward with their vision. This analysis will answer the following questions:
#
# **Total Enrollment**
# 1. How many students have enrolled at Coursera?
#
# **Organizations**
# 1. Which ten organizations offer educational content with the highest enrollment at Coursera?
# 2. Which ten organizations offer the most highest number of courses?
#
# **Courses**
# 1. How many courses are taught at Coursera?
# 2. What are the top ten course titles at Coursera?
#
# **Difficulty Levels**
# 1. What are the difficulty levels of courses at Coursea?
# 2. What is the enrollment numbers in courses at each difficulty level?
#
# **Certificates**
# 1. What types of certificates can students earn at Coursera?
# 2. What is the total number of each type of certificate offered?
#
# **Ratings**
# 1. What are the top ten highest rated courses at Coursera?
# 2. What are the bottom ten lowest rated courses?
# 3. What are the top ten highest rated educational organizations?
# 4. What are the bottom ten lowest rated organizations?
#
# **Correlations**
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 3. What is the correlation between certificate type and enrollement?
# 4. What is the correlation between certificate type and rating?
#
# **Imrpovements**
# 1. What can Tilto, Inc. learn from Coursera?
# 2. How can Tilto become a better organization than Coursera?

# %% [markdown]
# # Importing Libraries and Loading Data

# %% [markdown]
# ## Importing Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings # Supresses FutureWarning that are unnecessary.

# %% [markdown]
# ## Loading Data in Pandas
#
# The data is a csv file that I have dowloaded from Kaggle. In this section, I create a pandas dataframe object so I can work with the data.

# %%
coursera = pd.read_csv('C:\py\Projects\TuringCollege\Coursera\DataSet\coursera.csv', index_col = 0, skipinitialspace = True)

# %% [markdown]
# # Basic Information
#
# In this section, I will display the following information about this dataset:
#
# 1. Number of rows and columns
# 2. Total number of data enteries
# 3. The first 5 rows
# 4. The data types in this dataset

# %% [markdown]
# ## Number of Rows and Columns
#
# This dataset is made of 891 rows and 6 columns.

# %%
coursera.shape
# Out:
# (891, 6)

# %% [markdown]
# ## Number of Entries
#
# This dataset is made of 5346 data enteries.

# %%
coursera.size
# Out:
# 5346

# %% [markdown]
# ## The First Ten Rows

# %%
pd.set_option("display.max.columns", None) 
coursera.sort_index(inplace=True)
coursera.head(10)
# Out:
#                           course_title         course_organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#     course_Certificate_type  course_rating course_difficulty  \
# 0  PROFESSIONAL CERTIFICATE            4.6          Beginner
# 1            SPECIALIZATION            4.6          Beginner
# 2                    COURSE            4.9             Mixed
# 3            SPECIALIZATION            4.8          Beginner
# 4  PROFESSIONAL CERTIFICATE            4.8          Beginner
# 5            SPECIALIZATION            4.8      Intermediate
# 6                    COURSE            4.9             Mixed
# 7            SPECIALIZATION            4.7          Beginner
# 8            SPECIALIZATION            4.6          Beginner
# 9  PROFESSIONAL CERTIFICATE            4.7      Intermediate
#
#   course_students_enrolled
# 0                     480k
# 1                     310k
# 2                     2.5m
# 3                     1.5m
# 4                     350k
# 5                     690k
# 6                     3.2m
# 7                     510k
# 8                     220k
# 9                     310k

# %% [markdown]
# ## Data Types
#
# All data types of this dataset are string except course_rating, which is a float.

# %%
coursera.dtypes
# Out:
# course_title                 object
# course_organization          object
# course_Certificate_type      object
# course_rating               float64
# course_difficulty            object
# course_students_enrolled     object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values
# This dataset has no missing values

# %%
coursera.isnull().sum()
# Out:
# course_title                0
# course_organization         0
# course_Certificate_type     0
# course_rating               0
# course_difficulty           0
# course_students_enrolled    0
# dtype: int64

# %% [markdown]
# ## Duplicate Values
#
# This dataset has no duplicate values.

# %%
coursera[coursera.duplicated(keep = False)].sum()
# Out:
# course_title                0.0
# course_organization         0.0
# course_Certificate_type     0.0
# course_rating               0.0
# course_difficulty           0.0
# course_students_enrolled    0.0
# dtype: float64

# %% [markdown]
# ## Modification of Column Names
#
# I modified the name of each column to be clearer and more attractive.

# %%
coursera.rename(columns = {'course_title':'Course', 
                           'course_organization':'Organization', 
                           'course_Certificate_type':'Certificate',
                           'course_rating':'Rating',
                          'course_difficulty':'Difficulty',
                          'course_students_enrolled':'Students'}, inplace = True)

# %%
coursera.head(10)
# Out:
#                                 Course                Organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#                 Certificate  Rating    Difficulty Students
# 0  PROFESSIONAL CERTIFICATE     4.6      Beginner     480k
# 1            SPECIALIZATION     4.6      Beginner     310k
# 2                    COURSE     4.9         Mixed     2.5m
# 3            SPECIALIZATION     4.8      Beginner     1.5m
# 4  PROFESSIONAL CERTIFICATE     4.8      Beginner     350k
# 5            SPECIALIZATION     4.8  Intermediate     690k
# 6                    COURSE     4.9         Mixed     3.2m
# 7            SPECIALIZATION     4.7      Beginner     510k
# 8            SPECIALIZATION     4.6      Beginner     220k
# 9  PROFESSIONAL CERTIFICATE     4.7  Intermediate     310k

# %% [markdown]
# ## Modification of Certificate Column
#
# I modified the Certificate column so the text is in title case. I also removed the uncessary text, 'Certificate' from some of the enteries.

# %%
# Makes each string into title case.
coursera['Certificate'] = coursera['Certificate'].str.title()

# Removes text 'Certificate' from any value in this column.
coursera['Certificate'] = coursera['Certificate'].str.replace(r'Certificate', '') 

# Removes ALL white spaces from values of this column.
coursera['Certificate'].str.strip()

coursera.head(10)
# Out:
#                                 Course                Organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#       Certificate  Rating    Difficulty Students
# 0   Professional      4.6      Beginner     480k
# 1  Specialization     4.6      Beginner     310k
# 2          Course     4.9         Mixed     2.5m
# 3  Specialization     4.8      Beginner     1.5m
# 4   Professional      4.8      Beginner     350k
# 5  Specialization     4.8  Intermediate     690k
# 6          Course     4.9         Mixed     3.2m
# 7  Specialization     4.7      Beginner     510k
# 8  Specialization     4.6      Beginner     220k
# 9   Professional      4.7  Intermediate     310k

# %% [markdown]
# ## Modification of Student Column
#
# I modified this column so it's values are in integer format.

# %%
# Extractes the symbol 'k' or 'm' from the text in the Enrollment column. Created a new column called 'Symbol' for it.
coursera['Symbol'] = coursera['Students'].str[-1:]
coursera.Symbol.unique()
# Out:
# array(['k', 'm'], dtype=object)

# %%
# Extractes the digits from the Enrollment column and set the digits as float.
pd.set_option("max_rows", None)
coursera['Students'] = coursera['Students'].str.extract(r'(\d+[.\d]*)').astype(float)

# %%
# If the 'Symbol' column shows 'k', the number in the Enrollment column is multiplied by 1000.
# If it shows 'm', the number is multiplied by 1,000,000.
coursera.loc[coursera['Symbol'] == 'k', 'Multiple'] = 1000
coursera.loc[coursera['Symbol'] == 'm', 'Multiple'] = 1000000
coursera['Multiple'] = coursera['Multiple'].astype(int)

# %%
# Creates a new column called, 'Enrolled' with the product of the multiplication above.
coursera['Enrollment'] = coursera['Students'] * coursera['Multiple']
coursera['Enrollment'] = coursera['Enrollment'].astype(int)

# %%
# Deletes the unnecssary columns after the operations above. 
coursera = coursera.drop(['Symbol', 'Multiple', 'Students'], axis = 1)

# %%
coursera.head(10)
# Out:
#                                 Course                Organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#       Certificate  Rating    Difficulty  Enrollment
# 0   Professional      4.6      Beginner      480000
# 1  Specialization     4.6      Beginner      310000
# 2          Course     4.9         Mixed     2500000
# 3  Specialization     4.8      Beginner     1500000
# 4   Professional      4.8      Beginner      350000
# 5  Specialization     4.8  Intermediate      690000
# 6          Course     4.9         Mixed     3200000
# 7  Specialization     4.7      Beginner      510000
# 8  Specialization     4.6      Beginner      220000
# 9   Professional      4.7  Intermediate      310000

# %% [markdown]
# ## Modification of Column Order
#
# I modified the order of the columns to make the dataset more readable and workable.

# %%
coursera = coursera[['Organization', 'Course', 'Difficulty', 'Certificate', 'Enrollment', 'Rating']]
coursera.head(10)
# Out:
#                  Organization                               Course  \
# 0                         IBM                     IBM Data Science
# 1                         IBM         Introduction to Data Science
# 2             Yale University            The Science of Well-Being
# 3      University of Michigan                 Python for Everybody
# 4                      Google                    Google IT Support
# 5             deeplearning.ai                        Deep Learning
# 6         Stanford University                     Machine Learning
# 7  University of Pennsylvania                 Business Foundations
# 8                         IBM                 Applied Data Science
# 9                Google Cloud  Cloud Engineering with Google Cloud
#
#      Difficulty     Certificate  Enrollment  Rating
# 0      Beginner   Professional       480000     4.6
# 1      Beginner  Specialization      310000     4.6
# 2         Mixed          Course     2500000     4.9
# 3      Beginner  Specialization     1500000     4.8
# 4      Beginner   Professional       350000     4.8
# 5  Intermediate  Specialization      690000     4.8
# 6         Mixed          Course     3200000     4.9
# 7      Beginner  Specialization      510000     4.7
# 8      Beginner  Specialization      220000     4.6
# 9  Intermediate   Professional       310000     4.7

# %% [markdown]
# # Descriptive Statistics
#
# In this section, I provide basic statistical details and summarize the data on the 2 numerical features of this dataset, 'Enrollment' and 'Rating'.
#
# 1.  **Rating:** The subjective 1 - 5 score that students give at the end of a course.
# 2.  **Enrollment:** Total student enrollment in a course.

# %%
coursera.describe().applymap('{:,.2f}'.format)
# Out:
#          Enrollment  Rating
# count        891.00  891.00
# mean      90,552.08    4.68
# std      181,936.45    0.16
# min        1,500.00    3.30
# 25%       17,500.00    4.60
# 50%       42,000.00    4.70
# 75%       99,500.00    4.80
# max    3,200,000.00    5.00

# %% [markdown]
# # Outliers
#
# An outlier is an observation that is unlike the other observations. There are basically three causes for outliers:
#
# 1. Data entry and measurement errors
# 2. Sampling problems
# 3. Natural variations
#
# Outliers can capture valuable information and excluding them has to be done with caution. In my opinion, the outliers in this dataset fit the third cause, natural variations. Even though there are values that do not fit with the pattern of the rest of the data, in my opinion, the extreme values are legitimate, and I left them in the dataset.
#
# I used the **Interquartile Range (IQR)** method to identify outliers. The IQR is calculated as the difference between the 75th and the 25th percentiles of the data and defines the box in a box and whisker plot. On a box and whisker plot, values that fall outside of the box are drawn as dots and are considred outliers.
#
# According to the statistical methodology that I used, there are outliers in the following features:
#
# 1. Enrollment: 78
# 2. Rating: 17

# %%
# Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
Q1 = coursera.quantile(0.25)
Q3 = coursera.quantile(0.75)
IQR = Q3 - Q1

outliers_df = (coursera < (Q1 - 1.5 * IQR)) | (
    coursera > (Q3 + 1.5 * IQR)
)

((coursera < (Q1 - 1.5 * IQR)) | (coursera > (Q3 + 1.5 * IQR))).sum()
# Out:
# Certificate      0
# Course           0
# Difficulty       0
# Enrollment      78
# Organization     0
# Rating          17
# dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))
plt.tight_layout()

ax = sns.boxplot(ax=axes[0], data = coursera, x = coursera ['Rating'], palette='pastel')
ax = sns.boxplot(ax=axes[1], data = coursera, x = coursera ['Enrollment'], palette='pastel')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Total Enrollment
#
# The total enrollment at Coursera is: 80,681,900

# %%
total_enrollment = coursera['Enrollment'].sum()
total_enrollment
# Out:
# 80681900

# %% [markdown]
# ## Total Number of Courses
#
# Coursera offers 888 unique course titles.

# %%
total_courses = len(coursera['Course'].unique().tolist())
total_courses
# Out:
# 888

# %% [markdown]
# ## Organizations
#
# In this section, I will answer the following questions:
#
# 1. Which ten organizations have the highest enrollment?
# 2. Which ten organizations have the lowest enrollment?
# 3. Which ten organizations have the highest number of courses?
# 4. Which ten organizations have the lowest number of courses?

# %%
highest_enrollment = coursera.pivot_table('Enrollment', index = 'Organization', aggfunc ='sum', 
                                    margins = True, margins_name = 'Total Enrollment')
highest_enrollment = highest_enrollment.sort_values('Enrollment', ascending = False).head(11)
highest_enrollment = highest_enrollment.drop('Total Enrollment', axis=0)
highest_enrollment['Percentage'] = (highest_enrollment['Enrollment'] / total_enrollment) * 100
highest_enrollment = highest_enrollment.reset_index()
highest_enrollment
# Out:
#                        Organization  Enrollment  Percentage
# 0            University of Michigan     7437700    9.218548
# 1        University of Pennsylvania     5501300    6.818506
# 2               Stanford University     4854000    6.016219
# 3  University of California, Irvine     4326000    5.361797
# 4          Johns Hopkins University     4298900    5.328209
# 5                   Duke University     3967600    4.917584
# 6                   Yale University     3952000    4.898249
# 7                               IBM     2956400    3.664267
# 8                   deeplearning.ai     2863400    3.548999
# 9                      Google Cloud     2604300    3.227862

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Organization', data = highest_enrollment, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt= '%.0f%%')

plt.tight_layout()
plt.title("Top 10 Highest Enrollment by Organizations", fontsize = 35, pad = 30)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %%
lowest_enrollment = coursera.pivot_table('Enrollment', index = 'Organization', aggfunc ='sum', 
                                    margins = True, margins_name = 'Total Enrollment')
lowest_enrollment = lowest_enrollment.sort_values('Enrollment', ascending = False).tail(10)
lowest_enrollment['Percentage'] = (lowest_enrollment['Enrollment'] / total_enrollment) * 100
lowest_enrollment = lowest_enrollment.reset_index()
lowest_enrollment
# Out:
#                                         Organization  Enrollment  Percentage
# 0                        The University of Hong Kong        9500    0.011775
# 1                Fundação Instituto de Administração        9200    0.011403
# 2                                 Palo Alto Networks        9100    0.011279
# 3                                   Crece con Google        8800    0.010907
# 4                      Novosibirsk State University         8200    0.010163
# 5                           UCL School of Management        7800    0.009668
# 6                               ESCP Business School        6500    0.008056
# 7                           University of New Mexico        5500    0.006817
# 8  Peter the Great St. Petersburg Polytechnic Uni...        2400    0.002975
# 9                                Automation Anywhere        2200    0.002727

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Organization', data = lowest_enrollment, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.2f%%')


plt.tight_layout()
plt.title("Bottom 10 Lowest Enrollment by Organizations", fontsize = 35, pad = 30)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %%
highest_course_numbers = coursera.pivot_table('Course', index = 'Organization', aggfunc ='count', dropna = True)

highest_course_numbers = highest_course_numbers.sort_values('Course', ascending = False).head(11)
highest_course_numbers['Percentage'] = (highest_course_numbers['Course'] / total_courses) * 100
highest_course_numbers = highest_course_numbers.reset_index()
highest_course_numbers
# Out:
#                                   Organization  Course  Percentage
# 0                   University of Pennsylvania      59    6.644144
# 1                       University of Michigan      41    4.617117
# 2                                 Google Cloud      34    3.828829
# 3                              Duke University      28    3.153153
# 4                     Johns Hopkins University      28    3.153153
# 5             University of California, Irvine      27    3.040541
# 6   University of Illinois at Urbana-Champaign      22    2.477477
# 7                                          IBM      22    2.477477
# 8              University of California, Davis      21    2.364865
# 9               University of Colorado Boulder      19    2.139640
# 10                      University of Virginia      19    2.139640

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Organization', data = highest_course_numbers, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.0f%%')


plt.tight_layout()
plt.title("Top 10 Highest Number of Courses by Organizations", fontsize = 35, pad = 30)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %%
organizations = coursera.pivot_table('Course', index = 'Organization', aggfunc ='count', dropna = True)
organizations.sort_values('Course', ascending = False).tail(10)
# Out:
#                                                     Course
# Organization
# Peter the Great St. Petersburg Polytechnic Univ...       1
# Palo Alto Networks                                       1
# Osmosis                                                  1
# Novosibirsk State University                             1
# National Taiwan University                               1
# National Arts Strategies                                 1
# Nanyang Technological University, Singapore              1
# McMaster University                                      1
# MathWorks                                                1
# École des Ponts ParisTech                                1

# %% [markdown]
# ## Courses
#
# In this section, I will answer the following questions:
#
# 1. How many unique course titles does Coursera offer?
# 2. What are the ten course titles with the highest enrollment?
# 3. What are the ten course titles with the lowest enrollment?

# %%
highest_enrollment_by_course = coursera.pivot_table('Enrollment', index = 'Course', aggfunc='sum')
highest_enrollment_by_course = highest_enrollment_by_course.sort_values('Enrollment', ascending = False).head(10)
highest_enrollment_by_course['Percentage'] = (highest_enrollment_by_course['Enrollment'] / total_enrollment) * 100
highest_enrollment_by_course = highest_enrollment_by_course.reset_index()
highest_enrollment_by_course
# Out:
#                                               Course  Enrollment  Percentage
# 0                                   Machine Learning     3490000    4.325629
# 1                          The Science of Well-Being     2500000    3.098588
# 2                               Python for Everybody     1500000    1.859153
# 3  Programming for Everybody (Getting Started wit...     1300000    1.611266
# 4                                       Data Science      830000    1.028731
# 5                                     Career Success      790000    0.979154
# 6                     English for Career Development      760000    0.941971
# 7  Successful Negotiation: Essential Strategies a...      750000    0.929577
# 8                  Data Science: Foundations using R      740000    0.917182
# 9                                      Deep Learning      690000    0.855210

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Course', data = highest_enrollment_by_course, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.0f%%')


plt.tight_layout()
plt.title("Top 10 Highest Enrollment by Course", fontsize = 35, pad = 30)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %%
lowest_enrollment_by_course = coursera.pivot_table('Enrollment', index = 'Course', aggfunc='sum')
lowest_enrollment_by_course = lowest_enrollment_by_course.sort_values('Enrollment', ascending = False).tail(10)
lowest_enrollment_by_course = lowest_enrollment_by_course.reset_index()
lowest_enrollment_by_course['Percentage'] = (lowest_enrollment_by_course['Enrollment'] / total_enrollment) * 100
lowest_enrollment_by_course
# Out:
#                                               Course  Enrollment  Percentage
# 0                  International Security Management        2200    0.002727
# 1  Implementing RPA with Cognitive Automation and...        2200    0.002727
# 2  Blended Language Learning: Design and Practice...        1900    0.002355
# 3                                            Esports        1800    0.002231
# 4                                     Healthcare Law        1700    0.002107
# 5              The Pronunciation of American English        1700    0.002107
# 6  Identifying, Monitoring, and Analyzing Risk an...        1700    0.002107
# 7        Blockchain Revolution in Financial Services        1600    0.001983
# 8                       Infectious Disease Modelling        1600    0.001983
# 9  El Abogado del Futuro: Legaltech y la Transfor...        1500    0.001859

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Course', data = lowest_enrollment_by_course, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.3f%%')


plt.tight_layout()
plt.title("Bottome 10 Lowest Enrollment by Course", fontsize = 35, pad = 30)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ## Difficulty Levels
#
# In this section, I will answer the following questions:
#
# 1. What are the different difficulty levels at Coursea?
# 2. What is the total enrollment of students at courses with each difficulty level?

# %% [markdown]
# Difficulty level of courses at Coursera are:
#
# 1. Beginner
# 2. Mixed
# 3. Intermediate
# 4. Advanced

# %%
coursera['Difficulty'].unique().tolist()
# Out:
# ['Beginner', 'Mixed', 'Intermediate', 'Advanced']

# %%
difficulty = coursera.pivot_table('Enrollment', index = 'Difficulty', aggfunc='sum', 
                                  margins=True, margins_name = 'Total Enrollment')
difficulty = difficulty.drop('Total Enrollment', axis=0)
difficulty = difficulty.sort_values('Enrollment', ascending = False).head(10)
difficulty = difficulty.reset_index()
difficulty['Percentage'] = (difficulty['Enrollment'] / total_enrollment) * 100
difficulty
# Out:
#      Difficulty  Enrollment  Percentage
# 0      Beginner    39921800   49.480491
# 1         Mixed    24989400   30.972746
# 2  Intermediate    14506300   17.979621
# 3      Advanced     1264400    1.567142

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Difficulty', data = difficulty, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.0f%%')


plt.tight_layout()
plt.title("Enrollment by Difficlty Level", fontsize = 35)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ## Certificates
#
# In this section, I will answer the following questions:
#
# 1. What types of certificates can students earn at Coursera?
# 2. What is the total number offered of each type of certificate?

# %% [markdown]
# Students at Coursera can earn the following certificates:
#
# 1. Professional
# 2. Specialization
# 3. Course

# %%
coursera['Certificate'].unique().tolist()
# Out:
# ['Professional ', 'Specialization', 'Course']

# %%
certificates = coursera.pivot_table('Enrollment', index = 'Certificate', aggfunc='sum', 
                                    margins=True, margins_name = 'Total Enrollment')
certificates = certificates.drop('Total Enrollment', axis=0)
certificates = certificates.sort_values('Enrollment', ascending = False).head(10)
certificates['Percentage'] = (certificates['Enrollment'] / total_enrollment) * 100
certificates = certificates.reset_index()
certificates
# Out:
#       Certificate  Enrollment  Percentage
# 0          Course    51131300   63.373941
# 1  Specialization    27262200   33.789735
# 2   Professional      2288400    2.836324

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Certificate', data = certificates, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.0f%%')


plt.tight_layout()
plt.title("Enrollment by Certificate Type", fontsize = 35)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ## Ratings
#
# In this section, I will answer the following questions:
#
# 1. What are the top ten highest rated courses?
# 2. What are the bottom ten lowest rated courses?
# 3. What are the top ten highest rated organizations?
# 4. What are the bottom ten lowest rated organizations?

# %%
top_ratings_courses = coursera.pivot_table('Rating', index = 'Course')
top_ratings_courses = top_ratings_courses.sort_values('Rating', ascending = False).head(10).applymap('{:,.2f}'.format)
top_ratings_courses = top_ratings_courses.reset_index()
top_ratings_courses
# Out:
#                                               Course Rating
# 0                       Infectious Disease Modelling   5.00
# 1  El Abogado del Futuro: Legaltech y la Transfor...   5.00
# 2                               Stories of Infection   4.90
# 3                 Boosting Creativity for Innovation   4.90
# 4  Brand Management: Aligning Business, Brand and...   4.90
# 5  Understanding Einstein: The Special Theory of ...   4.90
# 6                Bugs 101: Insect-Human Interactions   4.90
# 7  Build a Modern Computer from First Principles:...   4.90
# 8                         Introduction to Psychology   4.90
# 9      Everyday Parenting: The ABCs of Child Rearing   4.90

# %%
bottom_ratings_courses = coursera.pivot_table('Rating', index = 'Course')
bottom_ratings_courses = bottom_ratings_courses.sort_values('Rating', ascending = False).tail(10).applymap('{:,.2f}'.format)
bottom_ratings_courses = bottom_ratings_courses.reset_index()
bottom_ratings_courses
# Out:
#                                               Course Rating
# 0                                Optical Engineering   4.20
# 1                 Foundations of Marketing Analytics   4.20
# 2  Instructional Design Foundations and Applications   4.20
# 3                     How to Start Your Own Business   4.10
# 4    Introduction to Trading, Machine Learning & GCP   4.00
# 5              Mathematics for Machine Learning: PCA   4.00
# 6                     iOS App Development with Swift   3.90
# 7                       Machine Learning for Trading   3.90
# 8  Machine Learning and Reinforcement Learning in...   3.70
# 9  How To Create a Website in a Weekend! (Project...   3.30

# %%
top_ratings_organizations = coursera.pivot_table('Rating', index = 'Organization')
top_ratings_organizations = top_ratings_organizations.sort_values('Rating', ascending = False).head(10).applymap('{:,.2f}'.format)
top_ratings_organizations = top_ratings_organizations.reset_index()
top_ratings_organizations
# Out:
#                                   Organization Rating
# 0               Hebrew University of Jerusalem   4.90
# 1  Nanyang Technological University, Singapore   4.90
# 2            Universidade Estadual de Campinas   4.90
# 3                             Crece con Google   4.90
# 4                       London Business School   4.90
# 5                    Google - Spectrum Sharing   4.90
# 6                                    ScrumTrek   4.90
# 7                    Universidade de São Paulo   4.87
# 8                    The University of Chicago   4.85
# 9                     Universidad de los Andes   4.82

# %% [markdown]
# The bottom 10 lowest rated organizations at Coursera are:
#
# 1. Peter the Great St. Petersburg Polytechnic University: 4.40
# 2. American Institute of Business and Economics: 4.40
# 3. Icahn School of Medicine at Mount Sinai: 4.40
# 4. Novosibirsk State University: 4.40
# 5. The Linux Foundation: 4.40
# 6. Luther College at the University of Regina: 4.40
# 7. Unity: 4.35
# 8. New York Institute of Finance: 4.30
# 9. Tsinghua University: 4.30
# 10. The State University of New York: 4.27

# %%
bottom_ratings_organizations = coursera.pivot_table('Rating', index = 'Organization')
bottom_ratings_organizations = bottom_ratings_organizations.sort_values('Rating', ascending = False).tail(10).applymap('{:,.2f}'.format)
bottom_ratings_organizations = bottom_ratings_organizations.reset_index()
bottom_ratings_organizations
# Out:
#                                         Organization Rating
# 0  Peter the Great St. Petersburg Polytechnic Uni...   4.40
# 1       American Institute of Business and Economics   4.40
# 2            Icahn School of Medicine at Mount Sinai   4.40
# 3                      Novosibirsk State University    4.40
# 4                               The Linux Foundation   4.40
# 5         Luther College at the University of Regina   4.40
# 6                                              Unity   4.35
# 7                      New York Institute of Finance   4.30
# 8                                Tsinghua University   4.30
# 9                   The State University of New York   4.27

# %% [markdown]
# # Correlations
#
# In this section, I will answer the following questions:
#
# 1. How does course difficulty level compare with rating?
# 2. How does course certificate type compare with rating?

# %% [markdown]
# ## What is the corrleations between difficulty level and rating?

# %%
difficulty_ratings = coursera.pivot_table('Rating', index = 'Difficulty', aggfunc='mean')
difficulty_ratings = difficulty_ratings.sort_values('Rating', ascending = False).applymap('{:,.2f}'.format).astype(float)
difficulty_ratings = difficulty_ratings.reset_index()
difficulty_ratings
# Out:
#      Difficulty  Rating
# 0         Mixed    4.71
# 1      Beginner    4.68
# 2  Intermediate    4.65
# 3      Advanced    4.60

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Rating', y = 'Difficulty', data = difficulty_ratings, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.2f')

plt.tight_layout()
plt.title("Rating by Difficulty Level", fontsize = 35)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ## What is the correlation between certificate type and rating?

# %%
certificate_ratings = coursera.pivot_table('Rating', index = 'Certificate', aggfunc='mean')
certificate_ratings = certificate_ratings.sort_values('Rating', ascending = False).applymap('{:,.2f}'.format).astype(float)
certificate_ratings = certificate_ratings.reset_index()
certificate_ratings
# Out:
#       Certificate  Rating
# 0          Course    4.71
# 1   Professional     4.70
# 2  Specialization    4.62

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Rating', y = 'Certificate', data = certificate_ratings, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.2f')

plt.tight_layout()
plt.title("Rating by Type of Certificate", fontsize = 35)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# ## What is the correlation between enrollment and rating?

# %%
enrollment_ratings = coursera.pivot_table('Enrollment', index = 'Rating', aggfunc ='sum', 
                                          margins=True, margins_name = 'Total Enrollment')
enrollment_ratings = enrollment_ratings.drop('Total Enrollment', axis=0)
enrollment_ratings = enrollment_ratings.sort_values('Enrollment', ascending = False)
enrollment_ratings = enrollment_ratings.reset_index()
enrollment_ratings['Percentage'] = (enrollment_ratings['Enrollment'] / total_enrollment) * 100

enrollment_ratings['Rating'] = enrollment_ratings['Rating'].astype(str)

# %%
plt.figure(figsize=(20,15))

ax = sns.barplot(x = 'Percentage', y = 'Rating', data = enrollment_ratings, ci = None, palette='pastel')

ax.bar_label(ax.containers[0], size = 25, fmt='%.3f%%')

plt.tight_layout()
plt.title("Enrollment by Rating", fontsize = 35)
plt.xticks([])
plt.yticks(fontsize = 25)
ax.tick_params(bottom = False, left = True)
plt.ylabel("")
plt.xlabel("")
sns.despine(bottom=True, left=True)
plt.show()

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1. Offering **BIGINNER LEVEL** courses will **INCREASE** enrollment.
# > * Only about 1.5% of enrollment is in courses of Advanced difficulty level. <br>
# > * Approximately 50% of enrollment at Coursera is in courses of Beginner difficulty level. <br>
# > * Approximately 80% of enrollment at Coursera is in courses of Beginner or Mixed difficulty level. <br>
#
# 2. Offering courses from **SPECIFIC ORGANIZATIONS** will **INCREASE** enrollment.
# > * Approximately 50% of enrollment were in courses from the top 10 organizations. <br>
# > * Only about 10% of enrollment were in courses from the bottom 10 organizations.
#
# 3. There are **SPECIFIC ORGANIZATIONS** that are more **PROLIFIC COURSE CREATORS**.
# > * Most of the courses were taught by organizations in the top 10. <br>
# > * The magority or organizations had fewer than 5 course offerings.
#
# 4. Offering courses from **TECHNOLOGY** sector will **INCREASE** enrollment.
# > * The majority of enrollment were in courses in the technology sector. <br>
# > * Only ...% of enrollment were in courses were in non-technolgy sector.
#
# 5. The **HIGHEST RATED COURSES** are **NOT** in the **TECHNOLOGY** sector.
# > * The courses in the technology sector were not the most highly rated. <br>
# > * ...% of highly rated courses were in non-technology sector.
#
# 6. The **HIGHEST RATED ORGANIZATIONS** are **NOT AMERICAN**.
# > * The most highly rated organizations are not American. <br>

# %% [markdown]
# # Suggestions

# %% [markdown]
# More knowledge about the particular characteristics of each feature of this dataset could improve the analysis. Furthermore, this analysis could be improved by focusing on one specific feature and identifying key ideas that could be useful in answering more specific questions.
