# %% [markdown]
# # 01Coursera

# %% [markdown]
# ##  Introduction
# Tilto, Inc. is a Lithuanian company, registered in the United States. Tilto is planning to become a company like Coursera which partners with more than 200 leading universities and companies to bring flexible, affordable, job-relevant online learning to individuals and organizations worldwide. Tilto means bridge in Lithuanian and the company plans to create a bridge between citizens of the world and their human potentials.
#
# Coursera was founded by Daphne Koller and Andrew Ng in 2012 with a vision of providing life-transforming learning experiences to learners around the world. Today, Coursera is a global online learning platform that offers anyone, anywhere, access to online courses and degrees from leading universities and companies.
#
# Titlo has a similar vision as Coursera. Tilto plans to become an international company that impacts the world by making its citizens realize their innate potentials. Therefore, its leaders wish to understand what makes Coursera successful. They also want to know what has not worked and become an even better organization than Coursera.
#
# For this analysis, I will work with a dataset provided by Coursea and obtained from Kaggle to help Tilto, Inc achieve their vision.

# %% [markdown]
# ## Goals
#
# The goal of this project is to analyze Coursera's current offering and advise Tilto's leadership on how to move forward with their vision. This analysis will answer the following questions:
#
# **Organizations**
# 1. What are the top ten organization at Coursera?
# 2. How many course titles does each organization have?
# 2. What are the top ten course titles taught by each organization?
#
# **Course**
# 1. How many courses are at Coursera?
# 2. What are the top ten course titles at Coursera?
#
# **Enrollment**
# 1. How many students in total have enrolled at Coursera?
# 2. What is the corrleation between difficulty of a course and number of enrolled students?
#
# **Certificates**
# 1. What types of certificates are provided at Coursera?
# 2. What number of each type of certificate are offered?
# 3. How does offereing certificates affect learner satisfaction?
# 4. Which type of certificate attracts attracts learners?
#
# **Ratings**
# 1. Which are the top ten highest rated courses by students?
# 2. Which are the top ten highest rated organizations?
# 3. Which are the bottom ten rated courses?
# 4. Which are the bottom ten rated organizations?
#
# **Difficulty**
# 1. What are the different difficulty levels at Coursea?
# 2. Which level of courses are more popular among learners?
# 3. Which level of difficlty attracts fewest learners?
#
# **Correlations**
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?
#
# **Imrpovements**
# 1. How can Tilto become a better organization than Coursera?

# %% [markdown]
# ## Importing Libraries and Loading Data

# %% [markdown]
# ### Importing Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings # Supresses FutureWarning that are unnecessary.

# %% [markdown]
# ### Loading Data in Pandas
#
# The data is a csv file that I have dowloaded from Kaggle. In this section, I create a pandas dataframe object so I can work with the data.

# %%
coursera = pd.read_csv('C:\py\Projects\TuringCollege\Coursera\DataSet\coursera.csv', index_col = 0, skipinitialspace = True)

# %% [markdown]
# ## Basic Information
#
# In this section, I will display the following information about this dataset:
#
# 1. Number of rows and columns
# 2. Total number of data enteries
# 3. The first 5 rows
# 4. The data types in this dataset

# %% [markdown]
# ### Number of Rows and Columns
#
# This dataset is made of 891 rows and 6 columns.

# %%
coursera.shape
# Out:
# (891, 6)

# %% [markdown]
# ### Total Number of Entries
#
# This dataset is made of 5346 data enteries.

# %%
coursera.size
# Out:
# 5346

# %% [markdown]
# ### The First Ten Rows

# %%
pd.set_option("display.max.columns", None) 
coursera.sort_index(inplace=True)
coursera
# Out:
#                                           course_title  \
# 0                                     IBM Data Science
# 1                         Introduction to Data Science
# 2                            The Science of Well-Being
# 3                                 Python for Everybody
# 4                                    Google IT Support
# ..                                                 ...
# 886                       Understanding Modern Finance
# 887                             Object-Oriented Design
# 888                     Aprende a programar con Python
# 889                                Погружение в Python
# 890  Compassionate Leadership Through Service Learn...
#
#                               course_organization   course_Certificate_type  \
# 0                                             IBM  PROFESSIONAL CERTIFICATE
# 1                                             IBM            SPECIALIZATION
# 2                                 Yale University                    COURSE
# 3                          University of Michigan            SPECIALIZATION
# 4                                          Google  PROFESSIONAL CERTIFICATE
# ..                                            ...                       ...
# 886  American Institute of Business and Economics            SPECIALIZATION
# 887                         University of Alberta                    COURSE
# 888                           Universidad Austral            SPECIALIZATION
# 889    Moscow Institute of Physics and Technology                    COURSE
# 890                University of Colorado Boulder                    COURSE
#
#      course_rating course_difficulty course_students_enrolled
# 0              4.6          Beginner                     480k
# 1              4.6          Beginner                     310k
# 2              4.9             Mixed                     2.5m
# 3              4.8          Beginner                     1.5m
# 4              4.8          Beginner                     350k
# ..             ...               ...                      ...
# 886            4.4      Intermediate                      11k
# 887            4.7      Intermediate                      33k
# 888            4.2          Beginner                     6.6k
# 889            4.7      Intermediate                      45k
# 890            4.9          Beginner                     6.4k
#
# [891 rows x 6 columns]

# %% [markdown]
# ### Data Types
#
# All data types of this dataset are string except for course_rating.

# %%
coursera.dtypes
# Out:
# course_title                 object
# course_organization          object
# course_Certificate_type      object
# course_rating               float64
# course_difficulty            object
# course_students_enrolled     object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Missing Values
# This dataset has no missing values

# %%
coursera.isnull().sum()
# Out:
# course_title                0
# course_organization         0
# course_Certificate_type     0
# course_rating               0
# course_difficulty           0
# course_students_enrolled    0
# dtype: int64

# %% [markdown]
# ### Duplicate Values
#
# This dataset has no duplicate values.

# %%
coursera[coursera.duplicated(keep = False)].sum()
# Out:
# course_title                0.0
# course_organization         0.0
# course_Certificate_type     0.0
# course_rating               0.0
# course_difficulty           0.0
# course_students_enrolled    0.0
# dtype: float64

# %% [markdown]
# ### Modification of Column Names
#
# I modified the name of each column to be clearer and more attractive.

# %%
coursera.rename(columns = {'course_title':'Course', 
                           'course_organization':'Organization', 
                           'course_Certificate_type':'Certificate',
                           'course_rating':'Rating',
                          'course_difficulty':'Difficulty',
                          'course_students_enrolled':'Students'}, inplace = True)

# %%
coursera.head()
# Out:
#                          Course            Organization  \
# 0              IBM Data Science                     IBM
# 1  Introduction to Data Science                     IBM
# 2     The Science of Well-Being         Yale University
# 3          Python for Everybody  University of Michigan
# 4             Google IT Support                  Google
#
#                 Certificate  Rating Difficulty Students
# 0  PROFESSIONAL CERTIFICATE     4.6   Beginner     480k
# 1            SPECIALIZATION     4.6   Beginner     310k
# 2                    COURSE     4.9      Mixed     2.5m
# 3            SPECIALIZATION     4.8   Beginner     1.5m
# 4  PROFESSIONAL CERTIFICATE     4.8   Beginner     350k

# %% [markdown]
# ### Modification of Certificate Column
#
# I modified the Certificate column so the text is in title case. I also removed the uncessary text, 'Certificate' from some of the enteries.

# %%
# Makes each string into title case.
coursera['Certificate'] = coursera['Certificate'].str.title()

# Removes text 'Certificate' from any value in this column.
coursera['Certificate'] = coursera['Certificate'].str.replace(r'Certificate', '') 

# Removes ALL white spaces from values of this column.
coursera['Certificate'].str.strip()

coursera.head(10)
# Out:
#                                 Course                Organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#       Certificate  Rating    Difficulty Students
# 0   Professional      4.6      Beginner     480k
# 1  Specialization     4.6      Beginner     310k
# 2          Course     4.9         Mixed     2.5m
# 3  Specialization     4.8      Beginner     1.5m
# 4   Professional      4.8      Beginner     350k
# 5  Specialization     4.8  Intermediate     690k
# 6          Course     4.9         Mixed     3.2m
# 7  Specialization     4.7      Beginner     510k
# 8  Specialization     4.6      Beginner     220k
# 9   Professional      4.7  Intermediate     310k

# %% [markdown]
# ### Modification of Enrollment Column
#
# I modified this column so numbers appear as comma-separated integers.

# %%
# Extractes the symbol 'k' or 'm' from the text in the Enrollment column. Created a new column called 'Symbol' for it.
coursera['Symbol'] = coursera['Students'].str[-1:]

# %%
# Extractes the digits from the Enrollment column and set the digits as float.
pd.set_option("max_rows", None)
coursera['Students'] = coursera['Students'].str.extract(r'(\d+[.\d]*)').astype(float)

# %%
# If the 'Symbol' column shows 'k', the number in the Enrollment column is multiplied by 1000.
# If it shows 'm', the number is multiplied by 1,000,000.
coursera.loc[coursera['Symbol'] == 'k', 'Multiple'] = 1000
coursera.loc[coursera['Symbol'] == 'm', 'Multiple'] = 1000000
coursera['Multiple'] = coursera['Multiple'].astype(int)

# %%
# Creates a new column called, 'Enrolled' with the product of the multiplication above.
# Formates the column to display numbers with comma separator on each 3 digits from the right.
coursera['Enrollment'] = coursera['Students'] * coursera['Multiple']
coursera['Enrollment'] = coursera['Enrollment'].astype(int)

# %%
# Deletes the unnecssary columns after the operations above. 
coursera = coursera.drop(['Symbol', 'Multiple', 'Students'], axis = 1)

# %%
coursera.head(10)
# Out:
#                                 Course                Organization  \
# 0                     IBM Data Science                         IBM
# 1         Introduction to Data Science                         IBM
# 2            The Science of Well-Being             Yale University
# 3                 Python for Everybody      University of Michigan
# 4                    Google IT Support                      Google
# 5                        Deep Learning             deeplearning.ai
# 6                     Machine Learning         Stanford University
# 7                 Business Foundations  University of Pennsylvania
# 8                 Applied Data Science                         IBM
# 9  Cloud Engineering with Google Cloud                Google Cloud
#
#       Certificate  Rating    Difficulty  Enrollment
# 0   Professional      4.6      Beginner      480000
# 1  Specialization     4.6      Beginner      310000
# 2          Course     4.9         Mixed     2500000
# 3  Specialization     4.8      Beginner     1500000
# 4   Professional      4.8      Beginner      350000
# 5  Specialization     4.8  Intermediate      690000
# 6          Course     4.9         Mixed     3200000
# 7  Specialization     4.7      Beginner      510000
# 8  Specialization     4.6      Beginner      220000
# 9   Professional      4.7  Intermediate      310000

# %% [markdown]
# ### Modification of Order of Columns
#
# I modified order of the columns to make it more readable and workable.

# %%
coursera = coursera[['Organization', 'Course', 'Difficulty', 'Certificate', 'Enrollment', 'Rating']]
coursera.head(10)
# Out:
#                  Organization                               Course  \
# 0                         IBM                     IBM Data Science
# 1                         IBM         Introduction to Data Science
# 2             Yale University            The Science of Well-Being
# 3      University of Michigan                 Python for Everybody
# 4                      Google                    Google IT Support
# 5             deeplearning.ai                        Deep Learning
# 6         Stanford University                     Machine Learning
# 7  University of Pennsylvania                 Business Foundations
# 8                         IBM                 Applied Data Science
# 9                Google Cloud  Cloud Engineering with Google Cloud
#
#      Difficulty     Certificate  Enrollment  Rating
# 0      Beginner   Professional       480000     4.6
# 1      Beginner  Specialization      310000     4.6
# 2         Mixed          Course     2500000     4.9
# 3      Beginner  Specialization     1500000     4.8
# 4      Beginner   Professional       350000     4.8
# 5  Intermediate  Specialization      690000     4.8
# 6         Mixed          Course     3200000     4.9
# 7      Beginner  Specialization      510000     4.7
# 8      Beginner  Specialization      220000     4.6
# 9  Intermediate   Professional       310000     4.7

# %% [markdown]
# ## Descriptive Statistics
#
# In this section, I provide basic statistical details summarize the data on 2 numerical features of this dataset.
#
# 1.  **Rating:** The subjective 1 - 5 score that students give at the end of a course based on various criterea.
# 2.  **Enrollment:** The number of students enrolled.

# %%
coursera.describe()
# Out:
#          Enrollment      Rating
# count  8.910000e+02  891.000000
# mean   9.055208e+04    4.677329
# std    1.819365e+05    0.162225
# min    1.500000e+03    3.300000
# 25%    1.750000e+04    4.600000
# 50%    4.200000e+04    4.700000
# 75%    9.950000e+04    4.800000
# max    3.200000e+06    5.000000

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)
# Out:
#   File "<ipython-input-273-60727d951ffa>", line 1
#     Ignores FutureWarning message that appears with the code below.
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-274-da30e6b8a7df> in <module>
#       1 fig, axes = plt.subplots(3, 3, figsize=(20, 20))
#       2
# ----> 3 sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
#       4 sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
#       5 sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
#
# NameError: name 'top_fifty' is not defined

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Organization

# %% [markdown]
# ### Course

# %% [markdown]
# ### Difficulty

# %% [markdown]
# ### Certificate

# %% [markdown]
# ### Enrollment

# %% [markdown]
# ### Rating

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)
# Out:
#                   Enrolled
# Difficulty
# Beginner     39,921,800.00
# Mixed        24,989,400.00
# Intermediate 14,506,300.00
# Advanced      1,264,400.00

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)
# Out:
#                     Enrolled
# Certificate
# Course         51,131,300.00
# Specialization 27,262,200.00
# Professional    2,288,400.00

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)
# Out:
#                                      Enrolled
# Organization
# University of Michigan           7,437,700.00
# University of Pennsylvania       5,501,300.00
# Stanford University              4,854,000.00
# University of California, Irvine 4,326,000.00
# Johns Hopkins University         4,298,900.00
# Duke University                  3,967,600.00
# Yale University                  3,952,000.00
# IBM                              2,956,400.00
# deeplearning.ai                  2,863,400.00
# Google Cloud                     2,604,300.00

# %% [markdown]
# ### Rating

# %% [markdown]
# #### Highest rated Courses

# %%
coursera.shape
# Out:
# (891, 6)

# %%
coursera.query('Rating ')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-279-781fadad2fa1> in <module>
# ----> 1 coursera.query('Rating ')
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3470
#    3471         try:
# -> 3472             result = self.loc[res]
#    3473         except ValueError:
#    3474             # when res is multi-dimensional loc raises, but this is sometimes a
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# c:\users\kevin nourian\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1319
#    1320             with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1321                 raise KeyError(
#    1322                     "Passing list-likes to .loc or [] with any missing labels "
#    1323                     "is no longer supported. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Float64Index([4.6, 4.6, 4.9, 4.8, 4.8,\n              ...\n              4.4, 4.7, 4.2, 4.7, 4.9],\n             dtype='float64', length=887). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
coursera.query('Rating == 5')
# Out:
#                                                  Title  \
# 401                       Infectious Disease Modelling
# 789  El Abogado del Futuro: Legaltech y la Transfor...
#
#                 Organization     Certificate  Rating    Difficulty  Enrolled
# 401  Imperial College London  Specialization    5.00  Intermediate  1,600.00
# 789      Universidad Austral          Course    5.00      Beginner  1,500.00

# %%
coursera.loc[(coursera.Rating == 5)]
# Out:
#                                                  Title  \
# 401                       Infectious Disease Modelling
# 789  El Abogado del Futuro: Legaltech y la Transfor...
#
#                 Organization     Certificate  Rating    Difficulty  Enrolled
# 401  Imperial College London  Specialization    5.00  Intermediate  1,600.00
# 789      Universidad Austral          Course    5.00      Beginner  1,500.00

# %%
coursera.loc[(coursera.Rating > 5) | (coursera.Certificate == 'Course')]
# Out:
#                                                  Title  \
# 2                            The Science of Well-Being
# 6                                     Machine Learning
# 14                                   Financial Markets
# 21                            COVID-19 Contact Tracing
# 29                          Introduction to Psychology
# 37                             Psychological First Aid
# 40   Successful Negotiation: Essential Strategies a...
# 41                      Technical Support Fundamentals
# 47   Programming for Everybody (Getting Started wit...
# 54                                     AI For Everyone
# 57                Primeros Auxilios Psicológicos (PAP)
# 62                   Neural Networks and Deep Learning
# 68            Stanford Introduction to Food and Health
# 69                             Writing in the Sciences
# 71   Viral Marketing and How to Craft Contagious Co...
# 72   Brand Management: Aligning Business, Brand and...
# 73          Management of Fashion and Luxury Companies
# 77     Fundamentals of Project Planning and Management
# 83                                   Social Psychology
# 85                   Financial Accounting Fundamentals
# 88                               What is Data Science?
# 90                            Learning to Teach Online
# 92               Excel Skills for Business: Essentials
# 99                                   Fashion as Design
# 100                     Design Thinking for Innovation
# 101                                 Modern Art & Ideas
# 102                         Food & Beverage Management
# 106  Become a CBRS Certified Professional Installer...
# 107     Camino a la Excelencia en Gestión de Proyectos
# 109  Finding Purpose and Meaning In Life: Living fo...
# 110                                  Indigenous Canada
# 111                             Python Data Structures
# 113                                  First Step Korean
# 114                 Private Equity and Venture Capital
# 121                                Science of Exercise
# 123  Improving Deep Neural Networks: Hyperparameter...
# 129                           AI for Medical Diagnosis
# 135          The Bits and Bytes of Computer Networking
# 136                          Introduction to Marketing
# 138                  The Strategy of Content Marketing
# 139       Design and Interpretation of Clinical Trials
# 141                                        Game Theory
# 144                          What Is Contemporary Art?
# 146                             Tools for Data Science
# 152                     Python for Data Science and AI
# 158   Financial Engineering and Risk Management Part I
# 159                    An Introduction to American Law
# 161                        Child Nutrition and Cooking
# 162                     Fundamentals of Graphic Design
# 165              Fundamentals of Quantitative Modeling
# 169                   Initiating and Planning Projects
# 173  Understanding Medical Research: Your Facebook ...
# 174          Forensic Accounting and Fraud Examination
# 175                     English for Career Development
# 176                      Moral Foundations of Politics
# 179                             Crash Course on Python
# 185  Vital Signs: Understanding What the Body Is Te...
# 187             Introduction to Data Science in Python
# 189              Structuring Machine Learning Projects
# 191  Étudier en France: French Intermediate course ...
# 192   Global Diplomacy – Diplomacy in the Modern World
# 193      International Women's Health and Human Rights
# 194              Introduction to the Biology of Cancer
# 198                           Data Science Methodology
# 199                    Using Python to Access Web Data
# 200                                   Sports Marketing
# 201                       Animal Behaviour and Welfare
# 204               Introduction to Financial Accounting
# 207                      Convolutional Neural Networks
# 210                           Autism Spectrum Disorder
# 212                          Agile with Atlassian Jira
# 213               Write Professional Emails in English
# 214                               Medical Neuroscience
# 216              Positive Psychiatry and Mental Health
# 218          Excel Skills for Business: Intermediate I
# 221         Computational Thinking for Problem Solving
# 223   Mathematics for Machine Learning: Linear Algebra
# 225          English for Business and Entrepreneurship
# 227  Google Cloud Platform Big Data and Machine Lea...
# 228  International Leadership and Organizational Be...
# 229                     Economics of Money and Banking
# 230  Introduction to TensorFlow for Artificial Inte...
# 232  Wine Tasting: Sensory Techniques for Wine Anal...
# 235                         Introduction to Philosophy
# 240  Positive Psychology: Martin E. P. Seligman’s V...
# 241                                  Marketing Digital
# 243                       The Data Scientist’s Toolbox
# 246     Entrepreneurship 1: Developing the Opportunity
# 249  Understanding the Brain: The Neurobiology of E...
# 250  Introduction to Systematic Review and Meta-Ana...
# 252         Nutrición y obesidad: control de sobrepeso
# 253                    Introduction to Dental Medicine
# 256                             Everyday Excel, Part 1
# 257              Finance for Non-Finance Professionals
# 260                 Learn to Program: The Fundamentals
# 261                     Understanding Research Methods
# 263                 Databases and SQL for Data Science
# 264        Machine Learning for Business Professionals
# 265  An Introduction to Consumer Neuroscience & Neu...
# 266  Advanced Valuation and Strategy - M&A, Private...
# 268                                       Gamification
# 269                                 Behavioral Finance
# 270                      Introductory Human Physiology
# 272  The Power of Macroeconomics: Economic Principl...
# 274                        The Global Financial Crisis
# 275  Clinical Terminology for International and U.S...
# 277                          Data Analysis with Python
# 278      Everyday Parenting: The ABCs of Child Rearing
# 279                                      Python Basics
# 280  International Law in Action: the Arbitration o...
# 281               AWS Fundamentals: Going Cloud-Native
# 282  The Manager's Toolkit: A Practical Guide to Ma...
# 283                           AI for Medical Prognosis
# 284                                     Project Launch
# 285                                    Sequence Models
# 287                          Greek and Roman Mythology
# 290                    Construction Project Management
# 291                                Positive Psychology
# 298  Terrorism and Counterterrorism: Comparing Theo...
# 300                    Contabilidad para no contadores
# 301  Corporate Sustainability. Understanding and Se...
# 302          Anatomy of the Chest, Abdomen, and Pelvis
# 303                             English for Journalism
# 304  Site Reliability Engineering: Measuring and Ma...
# 305         Communication Strategies for a Virtual Age
# 306                            Supply Chain Principles
# 307                              Introduction to HTML5
# 308            Introduction to Programming with MATLAB
# 310                       Marketing in a Digital World
# 311                            Learn to Speak Korean 1
# 312                     Introduction to Sustainability
# 314  Essentials in Clinical Simulations Across the ...
# 316   Operating Systems and You: Becoming a Power User
# 317                                      R Programming
# 318           In the Studio: Postwar Abstract Painting
# 319                        Essentials of Global Health
# 321                       Machine Learning with Python
# 322                            American Contract Law I
# 323          Oil & Gas Industry Operations and Markets
# 326                       Arts and Heritage Management
# 327  Introducción a la programación en Python I: Ap...
# 328  Supporting children with difficulties in readi...
# 329       HTML, CSS, and Javascript for Web Developers
# 330  Addiction Treatment: Clinical Skills for Healt...
# 331                              Réussir le Changement
# 332                               SQL for Data Science
# 334  Speak English Professionally: In Person, Onlin...
# 336                  Introduction to Corporate Finance
# 339            Introduction to Spreadsheets and Models
# 340              Introduction to Mathematical Thinking
# 341  Negociación exitosa: Estrategias y habilidades...
# 342                                     Drug Discovery
# 345  Instructional Design Foundations and Applications
# 346             International Organizations Management
# 347  Essential Google Cloud Infrastructure: Foundation
# 350                        Using Databases with Python
# 351   Epidemiology: The Basic Science of Public Health
# 353  Understanding Clinical Research: Behind the St...
# 354       Weight Management: Beyond Balancing Calories
# 357  The Modern World, Part One: Global History fro...
# 358        Convolutional Neural Networks in TensorFlow
# 359  e-Learning Ecologies: Innovative Approaches to...
# 361  The Sustainable Development Goals – A global, ...
# 362                                   People Analytics
# 364  Programming Foundations with JavaScript, HTML ...
# 365                              Innovation Management
# 369           Greening the Economy: Sustainable Cities
# 371                Creative Writing: The Craft of Plot
# 374       Python and Statistics for Financial Analysis
# 375  The Arts and Science of Relationships: Underst...
# 376                        Data-driven Decision Making
# 377                   Introduction to Forensic Science
# 378  Divide and Conquer, Sorting and Searching, and...
# 379                                    What is Social?
# 381    Digital Product Management: Modern Fundamentals
# 382          Financing and Investing in Infrastructure
# 383              Data Management for Clinical Research
# 384                             Supply Chain Logistics
# 385                            Grammar and Punctuation
# 386                 Revisão Sistemática e Meta-análise
# 388              Fundamentos de Finanzas Empresariales
# 389                Preparing to Manage Human Resources
# 392                          Dog Emotion and Cognition
# 395  Build a Modern Computer from First Principles:...
# 396        Financial Acumen for Non-Financial Managers
# 397                 Devenir entrepreneur du changement
# 398                               Operations Analytics
# 399                           Data Science Math Skills
# 400  Global Diplomacy: the United Nations in the World
# 403  System Administration and IT Infrastructure Se...
# 404  International Humanitarian Law in Theory and P...
# 406  Competencias digitales. Herramientas de ofimát...
# 408  IBM Customer Engagement Specialist Professiona...
# 410                          Business Model Innovation
# 411                 Getting Started with Google Sheets
# 412                           Introduction to Calculus
# 413                            A Law Student's Toolkit
# 414                   Rethinking International Tax Law
# 415  Fundamentals of Immunology: Innate Immunity an...
# 417         Introduction to International Criminal Law
# 418     Excel/VBA for Creative Problem Solving, Part 1
# 419         Excel Skills for Business: Intermediate II
# 420                     Data Visualization with Python
# 421                    Introduction to Classical Music
# 422      Getting Started with Google Kubernetes Engine
# 424       Public Policy Challenges of the 21st Century
# 425                                Fundamentals of GIS
# 427       Introduction to Artificial Intelligence (AI)
# 428             Introduction to User Experience Design
# 429                              Healing with the Arts
# 430  Design-Led Strategy: Design thinking for busin...
# 431          Natural Language Processing in TensorFlow
# 435                                Making Architecture
# 438      Troubles du spectre de l'autisme : diagnostic
# 440                      Social Norms, Social Change I
# 441          Fundamental Neuroscience for Neuroimaging
# 442                             FinTech Law and Policy
# 443               Inspiring and Motivating Individuals
# 444                      Equine Welfare and Management
# 446  Essential Google Cloud Infrastructure: Core Se...
# 447                  International Security Management
# 448                       Continuous Delivery & DevOps
# 449                                Marketing Gerencial
# 450     COVID-19: What You Need to Know (CME Eligible)
# 452                  Art & Ideas: Teaching with Themes
# 453    FinTech: Foundations, Payments, and Regulations
# 454  Essential Epidemiologic Tools for Public Healt...
# 455                                            Success
# 456  Beyond the Sustainable Development Goals (SDGs...
# 458                       Corporate Finance Essentials
# 460                                 The Addicted Brain
# 461  Engineering Health: Introduction to Yoga and P...
# 463                           Creative Problem Solving
# 464               Microeconomics: The Power of Markets
# 465     Understanding and Visualizing Data with Python
# 466  Teamwork Skills: Communicating Effectively in ...
# 467                 Managerial Accounting Fundamentals
# 469  Introduction to Cybersecurity Tools & Cyber At...
# 470  Mindshift: Break Through Obstacles to Learning...
# 471                                   Neurolinguistics
# 473               Introduction to Probability and Data
# 475             Fundamentals of Reinforcement Learning
# 476  IT Security: Defense against the digital dark ...
# 477     Politics and Economics of International Energy
# 478          Business Transformation with Google Cloud
# 479  Art & Activity: Interactive Strategies for Eng...
# 481          More Introduction to Financial Accounting
# 482                        Agile Meets Design Thinking
# 483                             Supply Chain Analytics
# 486                  Budgeting and Scheduling Projects
# 487                             Drug Commercialization
# 488                           AI For Medical Treatment
# 489                          Microeconomics Principles
# 490                    Dino 101: Dinosaur Paleobiology
# 491  Applied Plotting, Charting & Data Representati...
# 493  Bayesian Statistics: From Concept to Data Anal...
# 494       Ecology: Ecosystem Dynamics and Conservation
# 495  Introducción a Data Science: Programación Esta...
# 496        Entrepreneurship 2: Launching your Start-Up
# 499             Introduction to Genetics and Evolution
# 500  Understanding Einstein: The Special Theory of ...
# 501  Front-End Web UI Frameworks and Tools: Bootstr...
# 504                 Spanish Vocabulary: Meeting People
# 505                                     Model Thinking
# 506  Social and Economic Networks:  Models and Anal...
# 507                        The Art of Music Production
# 508  Anatomy: Musculoskeletal and Integumentary Sys...
# 509                        Feminism and Social Justice
# 510             Object-Oriented Data Structures in C++
# 511       Introduction to Environmental Law and Policy
# 512                                           Aprender
# 514  Anticorrupción: Introducción a conceptos y per...
# 515                                Solar Energy Basics
# 516            L'excellence opérationnelle en pratique
# 517  Miracles of Human Language: An Introduction to...
# 518   Java Programming: Solving Problems with Software
# 519                          De-Mystifying Mindfulness
# 520         Fundamentals of Visualization with Tableau
# 522  Design and Make Infographics (Project-Centered...
# 523  Modernizing Data Lakes and Data Warehouses wit...
# 524             The Science of Training Young Athletes
# 525                 Cameras, Exposure, and Photography
# 527    Epidemics - the Dynamics of Infectious Diseases
# 528  Mathematics for Machine Learning: Multivariate...
# 529  Transmedia Storytelling: Narrative worlds, eme...
# 530              Tricky American English Pronunciation
# 532  Renewable Energy and Green Building Entreprene...
# 533              Introduction to Operations Management
# 534  The Power of Microeconomics: Economic Principl...
# 535               Nutrition and Lifestyle in Pregnancy
# 536  Capstone: Retrieving, Processing, and Visualiz...
# 538               Getting Started with SAS Programming
# 539                                   Business Writing
# 540  Get Interactive: Practical Teaching with Techn...
# 541                 Les Fondamentaux de la Négociation
# 542                  Introduction to Personal Branding
# 543                                What is Compliance?
# 544                           Costos para los Negocios
# 546                         Kotlin for Java Developers
# 548          Introduction to Data Analysis Using Excel
# 549     Information Security: Context and Introduction
# 550                   Mastering Data Analysis in Excel
# 551  Aprendiendo a aprender: Poderosas herramientas...
# 552                                Finanzas personales
# 554        How Things Work: An Introduction to Physics
# 555          Python Functions, Files, and Dictionaries
# 556                 Managing Project Risks and Changes
# 557                         Introduction to Typography
# 558                  Managing Social and Human Capital
# 559         Teach English Now! Foundational Principles
# 560  Engineering Project Management: Initiating and...
# 561                                Algorithmic Toolbox
# 564  Elastic Google Cloud Infrastructure: Scaling a...
# 565  Biology Meets Programming: Bioinformatics for ...
# 566              Customer Segmentation and Prospecting
# 567  Geopolítica y gobernanza global: riesgos y opo...
# 568          Getting Started with AWS Machine Learning
# 570                 Epidemics, Pandemics and Outbreaks
# 572            Industrial IoT on Google Cloud Platform
# 575                            Mastering Final Cut Pro
# 576      The Oral Cavity: Portal to Health and Disease
# 577           Leadership in 21st Century Organizations
# 578                    Global Environmental Management
# 579  International Law in Action: A Guide to the In...
# 580                                 Sports and Society
# 581            Fundamentals of Engineering Exam Review
# 583  Sustainable Tourism – promoting environmental ...
# 584         Think Again I: How to Understand Arguments
# 585                           Machine Learning for All
# 586                       Julia Scientific Programming
# 587  The Horse Course: Introduction to Basic Care a...
# 588                Summary Statistics in Public Health
# 589                           Version Control with Git
# 590  Autodesk Certified Professional: Revit for Arc...
# 591                Excel Skills for Business: Advanced
# 593           International migrations: a global issue
# 594                    Introduction to Cloud Computing
# 595                             UX Design Fundamentals
# 597  Municipal Solid Waste Management in Developing...
# 598  English for Science, Technology, Engineering, ...
# 599  Democracia y decisiones públicas. Introducción...
# 600                    Songwriting: Writing the Lyrics
# 602         Bayesian Statistics: Techniques and Models
# 603  Using Python to Interact with the Operating Sy...
# 604                               Accounting Analytics
# 605                  Data Analytics for Lean Six Sigma
# 606  Positive Psychology: Applications and Interven...
# 608            Introduction to Blockchain Technologies
# 610  Building Scalable Java Microservices with Spri...
# 612                                    Access Controls
# 613                              English Composition I
# 616                      The Truth About Cats and Dogs
# 617  Introduction to Portfolio Construction and Ana...
# 619  Write A Feature Length Screenplay For Film Or ...
# 620                      Introduction to Breast Cancer
# 622  Resilience in Children Exposed to Trauma, Disa...
# 623   Entrepreneurship Strategy: From Ideation to Exit
# 624  Driving business towards the Sustainable Devel...
# 625                    Introduction to Web Development
# 626             Process Mining: Data science in Action
# 627                          Dermatology: Trip to skin
# 628              Introduction to Engineering Mechanics
# 629            Search Engine Optimization Fundamentals
# 630                 Applied Machine Learning in Python
# 631         AWS Fundamentals: Addressing Security Risk
# 632                                 Roman Architecture
# 633                       Fundamentals of Music Theory
# 634         Reporting extra-financier et stratégie RSE
# 635                A Life of Happiness and Fulfillment
# 636                           Egiptología (Egyptology)
# 637                      Applied Data Science Capstone
# 638                        Unraveling the Cycling City
# 639                           Japanese for beginners 1
# 641             Econometrics: Methods and Applications
# 642                                   Basic Statistics
# 643                   Global Energy and Climate Policy
# 645                 Boosting Creativity for Innovation
# 646             Positive Psychology: Resilience Skills
# 647                  Systems Thinking In Public Health
# 649  Introduction to Embedded Systems Software and ...
# 650                Gestión de organizaciones efectivas
# 651                          Arts and Culture Strategy
# 652                                      Mountains 101
# 653               Building Batch Data Pipelines on GCP
# 655      Code Yourself! An Introduction to Programming
# 656              Leading Healthcare Quality and Safety
# 657                               Stories of Infection
# 658       Recruiting, Hiring, and Onboarding Employees
# 659    Introduction to Trading, Machine Learning & GCP
# 660  Smart Cities – Management of Smart Urban Infra...
# 661  ADHD: Everyday Strategies for Elementary Students
# 662           C for Everyone: Programming Fundamentals
# 663                             Antibiotic Stewardship
# 664                               Introduction to CSS3
# 665                          Perfect Tenses and Modals
# 666                 The Technology of Music Production
# 667            Internet Connection: How to Get Online?
# 668       Periodismo digital y combate a las fake news
# 669                                    Marketing Verde
# 670  Building Conversational Experiences with Dialo...
# 671  The Modern World, Part Two: Global History sin...
# 672  Becoming a changemaker: Introduction to Social...
# 674  Design Thinking for the Greater Good: Innovati...
# 676                    Understanding Cancer Metastasis
# 677    The Social Context of Mental Health and Illness
# 678       Cuidado de heridas en el ámbito hospitalario
# 680           Stanford's Short Course on Breastfeeding
# 681                  Getting Started With Music Theory
# 683   Probabilistic Graphical Models 1: Representation
# 684                             Write Your First Novel
# 685                   Nanotechnology: A Maker’s Course
# 686  Data Visualization and Communication with Tableau
# 687                     Biohacking Your Brain's Health
# 688                Bugs 101: Insect-Human Interactions
# 689              Introduction to Intellectual Property
# 690                          The Science of Stem Cells
# 691  Corrección, estilo y  variaciones de la lengua...
# 692                     Practical Time Series Analysis
# 694                              Geopolitics of Europe
# 695               Sharpened Visions: A Poetry Workshop
# 696  The Science of Success: What Researchers Know ...
# 697                              Discrete Optimization
# 698                   From the Big Bang to Dark Energy
# 701                      International Cyber Conflicts
# 702  Autodesk Certified Professional: AutoCAD for D...
# 703                  Основы программирования на Python
# 704              Entrepreneurship 3: Growth Strategies
# 705                        Fundamentos de la escritura
# 706                        Modeling Risk and Realities
# 707  Ecosystem Services: a Method for Sustainable D...
# 708              Epigenetic Control of Gene Expression
# 710               Gut Check: Exploring Your Microbiome
# 711      Diseño y Creación de un Emprendimiento Social
# 712  Security & Safety Challenges in a Globalized W...
# 713  Introduction to Business Analytics: Communicat...
# 714                                 Corporate Strategy
# 715      Probability and Statistics: To p or not to p?
# 716  The hidden value – Lean in manufacturing and s...
# 718                               Chemicals and Health
# 719              Blockchain: Foundations and Use Cases
# 721                   Foundations of Business Strategy
# 723                      Introduction to Cyber Attacks
# 724                 Fundamentos de Excel para Negocios
# 725  Corporate & Commercial Law I: Contracts & Empl...
# 726                      Chicken Behaviour and Welfare
# 727                     Accounting for Decision Making
# 728      Construction Cost Estimating and Cost Control
# 729                  Introduction to Self-Driving Cars
# 730  Cuidados y procedimientos generales en la aten...
# 731                                  Project Execution
# 732                           Programming Fundamentals
# 734                            Getting Started with Go
# 735  Introduction to Thermodynamics: Transferring E...
# 736  Challenging Forensic Science: How Science Shou...
# 737                                  Chinese for HSK 1
# 738                       Business English: Networking
# 740             Global Trends for Business and Society
# 743  A Crash Course in Causality:  Inferring Causal...
# 744  Introduction to User Experience Principles and...
# 745                        Introduction to Electronics
# 746  Understanding Plants - Part I: What a Plant Knows
# 747  Innovation Through Design: Think, Make, Break,...
# 749                        Strategy and Sustainability
# 751  Blended Language Learning: Design and Practice...
# 753  Astrobiology and the Search for Extraterrestri...
# 755  Leading for Equity, Diversity and Inclusion in...
# 756                       Developing Your Musicianship
# 757                               Guitar for Beginners
# 758                Introduction to Systems Engineering
# 759  The Cycle: Management of Successful Arts and C...
# 760                            Supply Chain Operations
# 761  Global Financing Solutions  (by EDHEC and Soci...
# 762                           Intercultural Management
# 763                      Sample-based Learning Methods
# 764                    Dairy Production and Management
# 766  Introduction to Statistics & Data Analysis in ...
# 767  How To Create a Website in a Weekend! (Project...
# 768                          The Changing Global Order
# 769                 Love as a Force for Social Justice
# 770                            Enterprise Architecture
# 771  Ready, Set, Future! Introduction to Futures Th...
# 772                    Sexualidad...mucho más que sexo
# 773                      Effective Compliance Programs
# 774                        Introduction to Imagemaking
# 775                 Foundations of Everyday Leadership
# 776                            Becoming a Sports Agent
# 777                 Cloud Computing Basics (Cloud 101)
# 778                 Finance for Non-Financial Managers
# 780               Introduction to Computer Programming
# 782  Atención Primaria en Salud: El desafío de las ...
# 783         Data Collection and Processing with Python
# 784                         Music Business Foundations
# 785      Hacia una práctica constructivista en el aula
# 787                           Wonders of Ancient Egypt
# 788  Teaching Character and Creating Positive Class...
# 789  El Abogado del Futuro: Legaltech y la Transfor...
# 790         Functional Programming Principles in Scala
# 791                           Magic in the Middle Ages
# 792          Six Sigma and the Organization (Advanced)
# 794                            Construction Scheduling
# 795  New Approaches to Countering Terror: Counterin...
# 796  Managing Your Health: The Role of Physical The...
# 797   Ancient Philosophy: Aristotle and His Successors
# 799      Antimicrobial resistance - theory and methods
# 800                        Cómo hablar bien en público
# 801                               Strategic Management
# 802  Gender and Sexuality: Diversity and Inclusion ...
# 803     Hardware Description Languages for FPGA Design
# 804             Data Visualization with Advanced Excel
# 805                      Influencer Marketing Strategy
# 806                                      Dentistry 101
# 807        Teach English Now! Teaching Language Online
# 808  Preparing for the Google Cloud Associate Cloud...
# 810                               Patrocinio Deportivo
# 811             Математика и Python для анализа данных
# 813                      Decision-Making and Scenarios
# 814         Sleep: Neurobiology, Medicine, and Society
# 815                           Control of Mobile Robots
# 816                     BIM Fundamentals for Engineers
# 818                          The Science of Gastronomy
# 819                Aboriginal Worldviews and Education
# 820     Curanderismo: Traditional Healing Using Plants
# 821                  Cybersecurity and Its Ten Domains
# 822     Strategic Business Management - Microeconomics
# 823                               Quantitative Methods
# 824                    Building Your Leadership Skills
# 825                            Advertising and Society
# 827  Queering Identities: LGBTQ+ Sexuality and Gend...
# 828           AWS Fundamentals: Migrating to the Cloud
# 829                         What future for education?
# 830                       Introduction to Ableton Live
# 831  Machine Learning Foundations: A Case Study App...
# 832                                    EMT Foundations
# 833                                   Russian Alphabet
# 834  Internet Giants: The Law and Economics of Medi...
# 835           Global Financial Markets and Instruments
# 837  Instructional Methods in Health Professions Ed...
# 838  Actualización en el manejo del paciente con di...
# 839                              Legal Tech & Startups
# 840  Materials Science: 10 Things Every Engineer Sh...
# 841               Основы разработки на C++: белый пояс
# 842  Networking and Security Architecture with VMwa...
# 843                     Linear Circuits 1: DC Analysis
# 844                 Introduction aux Droits de l’Homme
# 845  High Performance Collaboration: Leadership, Te...
# 846  Agile и Scrum в работе над проектами и продуктами
# 847                         Estadística y probabilidad
# 848                      Classical Sociological Theory
# 849  Google Cloud Platform Fundamentals for AWS Pro...
# 850                   Introduction to Game Development
# 851    Formulación y evaluación de proyectos complejos
# 852             Digital Media and Marketing Strategies
# 853                                  Age of Cathedrals
# 854             Cost and Economics in Pricing Strategy
# 855                            Digital Business Models
# 856  Identifying, Monitoring, and Analyzing Risk an...
# 858  ¿Qué hacen los buenos directivos? Prioridades ...
# 859             Software Processes and Agile Practices
# 860  Scaling Operations: Linking Strategy and Execu...
# 861  AWS Fundamentals: Building Serverless Applicat...
# 862                           Introduction to Big Data
# 863               Front-End Web Development with React
# 864              The Economics of Health Care Delivery
# 866  Introdução à Ciência da Computação com Python ...
# 867           Osteoarchaeology: The Truth in Our Bones
# 869                     Python Classes and Inheritance
# 870           Electric Industry Operations and Markets
# 871  Data and Health Indicators in Public Health Pr...
# 872                  Particle Physics: an Introduction
# 873              Mathematics for Machine Learning: PCA
# 874                     A Crash Course in Data Science
# 876               Research Data Management and Sharing
# 877  Aspectos básicos de la planificación y la gest...
# 878               Introduction to Genomic Technologies
# 879   Introduction to Chemistry:  Reactions and Ratios
# 880                  Explorando la Energía Sustentable
# 882                                University Teaching
# 883               Психолингвистика (Psycholinguistics)
# 884  Building Resilient Streaming Analytics Systems...
# 887                             Object-Oriented Design
# 889                                Погружение в Python
# 890  Compassionate Leadership Through Service Learn...
#
#                                           Organization Certificate  Rating  \
# 2                                      Yale University      Course    4.90
# 6                                  Stanford University      Course    4.90
# 850         Mixed    79,000.00
# 851  Intermediate     4,400.00
# 852         Mixed    57,000.00
# 853      Beginner    21,000.00
# 854      Beginner    15,000.00
# 855      Beginner    21,000.00
# 856      Beginner     1,700.00
# 858      Beginner    25,000.00
# 859         Mixed    60,000.00
# 860         Mixed    12,000.00
# 861      Beginner    27,000.00
# 862         Mixed   160,000.00
# 863  Intermediate    45,000.00
# 864         Mixed     7,200.00
# 866      Beginner   120,000.00
# 867      Beginner    22,000.00
# 869  Intermediate    21,000.00
# 870      Beginner    12,000.00
# 871      Beginner    18,000.00
# 872         Mixed    42,000.00
# 873  Intermediate    33,000.00
# 874         Mixed   130,000.00
# 876         Mixed    16,000.00
# 877      Beginner    10,000.00
# 878         Mixed    42,000.00
# 879      Beginner    46,000.00
# 880      Beginner    28,000.00
# 882      Beginner     9,500.00
# 883         Mixed    21,000.00
# 884  Intermediate     5,800.00
# 887  Intermediate    33,000.00
# 889  Intermediate    45,000.00
# 890      Beginner     6,400.00

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)
# Out:
#                                             Rating
# Organization
# University of Pennsylvania                      59
# University of Michigan                          41
# Google Cloud                                    34
# Duke University                                 28
# Johns Hopkins University                        28
# University of California, Irvine                27
# University of Illinois at Urbana-Champaign      22
# IBM                                             22
# University of California, Davis                 21
# University of Colorado Boulder                  19

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)
# Out:
#               Rating
# Difficulty
# Beginner         487
# Intermediate     198
# Mixed            187
# Advanced          19

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)
# Out:
#                                             Title
# Organization
# University of Pennsylvania                     59
# University of Michigan                         41
# Google Cloud                                   34
# Duke University                                28
# Johns Hopkins University                       28
# University of California, Irvine               27
# University of Illinois at Urbana-Champaign     22
# IBM                                            22
# University of California, Davis                21
# University of Colorado Boulder                 19

# %% [markdown]
# ### Certificate

# %%
coursera.loc[(coursera.Certificate == "Specialization")].shape
# Out:
# (297, 6)

# %%
coursera.loc[coursera.Certificate.isin(['Course'])].shape
# Out:
# (582, 6)

# %%
coursera.loc[coursera.Certificate.isin(['Professional '])].shape
# Out:
# (12, 6)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# ### Correlation Among Features

# %% [markdown]
# ### Correlation Among Features
#
# In this section, I will answer the following questions:
#
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

# %% [markdown]
# ### What is the corrleation between difficulty of a course and number of enrolled students?

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %% [markdown]
# ### Correlation Among Features
#
# In this section, I will answer the following questions:
#
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

# %% [markdown]
# ### What is the corrleation between difficulty of a course and number of enrolled students?

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])

# %%
### Correlation Among Features 

In this section, I will answer the following questions:

1. What is the corrleations between difficulty level of a course and enrollment? 
2. What is the corrleations between difficulty level and rating?
2. What is the correlation between certificate type and enrollement? 
3. What is the correlation between certificate type and rating?

#### Difficulty vs Enrollment

difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

#### Certificate vs Rating

#### Certificate vs Enrollment

certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

#### Organization vs Enrollment

organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

### What is the corrleation between difficulty of a course and number of enrolled students?

#### Organization vs Rating

ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

#### Difficulty vs Rating

ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

## Outliers

Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning) 

Q1 = top_fifty.quantile(0.25)
Q3 = top_fifty.quantile(0.75)
IQR = Q3 - Q1

outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
    top_fifty > (Q3 + 1.5 * IQR)
)

((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2]) fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])

# %% [markdown]
# ### Correlation Among Features
#
# In this section, I will answer the following questions:
#
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

# %% [markdown]
# ### What is the corrleation between difficulty of a course and number of enrolled students?

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])

# %% [markdown]
# ### Correlation Among Features
#
# In this section, I will answer the following questions:
#
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

# %% [markdown]
# ### What is the corrleation between difficulty of a course and number of enrolled students?

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])

# %% [markdown]
# ### Correlation Among Features
#
# In this section, I will answer the following questions:
#
# 1. What is the corrleations between difficulty level of a course and enrollment?
# 2. What is the corrleations between difficulty level and rating?
# 2. What is the correlation between certificate type and enrollement?
# 3. What is the correlation between certificate type and rating?

# %% [markdown]
# #### Difficulty vs Enrollment

# %%
difficulty_enrollment = coursera.groupby("Difficulty")["Enrolled"].sum()
difficulty_enrollment.sort_values(ascending=False, inplace = True)
difficulty_enrollment_df = pd.DataFrame(difficulty_enrollment)
difficulty_enrollment_df.head(10)

# %% [markdown]
# #### Certificate vs Rating

# %% [markdown]
# #### Certificate vs Enrollment

# %%
certificate_enrollment = coursera.groupby("Certificate")["Enrolled"].sum()
certificate_enrollment.sort_values(ascending=False, inplace = True)
certificate_enrollment_df = pd.DataFrame(certificate_enrollment)
certificate_enrollment_df.head(10)

# %% [markdown]
# #### Organization vs Enrollment

# %%
organization_enrollment = coursera.groupby("Organization")["Enrolled"].sum()
organization_enrollment.sort_values(ascending=False, inplace = True)
organization_enrollment_df = pd.DataFrame(organization_enrollment)
organization_enrollment_df.head(10)

# %% [markdown]
# ### What is the corrleation between difficulty of a course and number of enrolled students?

# %% [markdown]
# #### Organization vs Rating

# %%
ratings_organization = coursera.groupby("Organization")["Rating"].count()
ratings_organization.sort_values(ascending=False, inplace = True)
ratings_organization_df = pd.DataFrame(ratings_organization)
ratings_organization_df.head(10)

# %% [markdown]
# #### Difficulty vs Rating

# %%
ratings_difficulty = coursera.groupby("Difficulty")["Rating"].count()
ratings_difficulty.sort_values(ascending=False, inplace = True)
ratings_difficulty_df = pd.DataFrame(ratings_difficulty)
ratings_difficulty_df.head(10)

# %%
organization_title = coursera.groupby("Organization")["Title"].count()
organization_title.sort_values(ascending=False, inplace = True)
organization_title_df = pd.DataFrame(organization_title)
organization_title_df.head(10)

# %% [markdown]
# ## Outliers

# %%
Ignores FutureWarning message that appears with the code below.

warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# Q1 = top_fifty.quantile(0.25)
# Q3 = top_fifty.quantile(0.75)
# IQR = Q3 - Q1
#
# outliers_df = (top_fifty < (Q1 - 1.5 * IQR)) | (
#     top_fifty > (Q3 + 1.5 * IQR)
# )
#
# ((top_fifty < (Q1 - 1.5 * IQR)) | (top_fifty > (Q3 + 1.5 * IQR))).sum()

# %%
fig, axes = plt.subplots(3, 3, figsize=(20, 20))

sns.boxplot(ax=axes[0, 0], data = top_fifty, x = top_fifty ['acousticness'])
sns.boxplot(ax=axes[0, 1], data = top_fifty, x = top_fifty ['danceability'])
sns.boxplot(ax=axes[0, 2], data = top_fifty, x = top_fifty ['duration_ms'])
sns.boxplot(ax=axes[1, 0], data = top_fifty, x = top_fifty ['instrumentalness'])
sns.boxplot(ax=axes[1, 1], data = top_fifty, x = top_fifty ['liveness'])
sns.boxplot(ax=axes[1, 2], data = top_fifty, x = top_fifty ['loudness'])
sns.boxplot(ax=axes[2, 0], data = top_fifty, x = top_fifty ['speechiness'])

fig.delaxes(ax = axes[2,1]) 
fig.delaxes(ax = axes[2,2])
